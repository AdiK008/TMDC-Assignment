# %% [markdown]
# #### Importing library

# %%
import json
import pandas as pd
from datetime import datetime

# %%
with open('data1.json') as f:
    data=json.load(f)

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#                     id               id_str  \
# 0  1465948889761173507  1465948889761173507
# 1  1466046988500230146  1466046988500230146
# 2  1466089777938280452  1466089777938280452
# 3  1466385507298983942  1466385507298983942
# 4  1466385504690008070  1466385504690008070
#
#                                            full_text               source  \
# 0  explosive—we learn trump tested positive covid...   Twitter for iPhone
# 1  learn wise guy mocked joe biden presidential d...   Twitter for iPhone
# 2  covid update total tests conducted last hrs ne...       Hootsuite Inc.
# 3  early south african data say omicron amp reinf...      Twitter Web App
# 4  largestvaccinedrive achieves another milestone...  Twitter for Android
#
#                             source_url  retweet_count  favorite_count lang  \
# 0   http://twitter.com/download/iphone           5273           11800   en
# 1   http://twitter.com/download/iphone           1964            6256   en
# 2            https://www.hootsuite.com            593             624   en
# 3           https://mobile.twitter.com             44               0   en
# 4  http://twitter.com/download/android             41               0   en
#
#                                   full_text_lemmatiz
# 0  [explosive—we, learn, trump, tested, positive,...
# 1  [learn, wise, guy, mocked, joe, biden, preside...
# 2  [covid, update, total, test, conducted, last, ...
# 3  [early, south, african, data, say, omicron, am...
# 4  [largestvaccinedrive, achieves, another, miles...

# %% [markdown]
# #### Creating Word Cloud

# %%
# word_cloud
# Import WordCloud and STOPWORDS
from wordcloud import WordCloud
# Import matplotlib
import matplotlib.pyplot as plt 


def word_cloud(text):

    # Create WordCloud 
    word_cloud = WordCloud(width = 550, height = 550, 
                           background_color ='white',  
                           min_font_size = 12).generate(text) 

    # Set wordcloud figure size
    plt.figure(figsize = (8, 6)) 

    # Show image
    plt.imshow(word_cloud) 

    # Remove Axis
    plt.axis("off")  

    # show plot
    plt.show()

# %%
paragraph=' '.join(df['full_text'].tolist())
word_cloud(paragraph)

# %% [markdown]
# #### Finding sentiment and polarity

# %%
from textblob import TextBlob
def sentiment(text):
    return TextBlob(text).sentiment.subjectivity

def polarity(text):
    return TextBlob(text).sentiment.polarity

# %%
df['sentiment']= df['full_text'].apply(sentiment)
df['polarity']= df['full_text'].apply(polarity)

# %%
df.head()
# Out:
#                     id               id_str  \
# 0  1465948889761173507  1465948889761173507
# 1  1466046988500230146  1466046988500230146
# 2  1466089777938280452  1466089777938280452
# 3  1466385507298983942  1466385507298983942
# 4  1466385504690008070  1466385504690008070
#
#                                            full_text               source  \
# 0  explosive—we learn trump tested positive covid...   Twitter for iPhone
# 1  learn wise guy mocked joe biden presidential d...   Twitter for iPhone
# 2  covid update total tests conducted last hrs ne...       Hootsuite Inc.
# 3  early south african data say omicron amp reinf...      Twitter Web App
# 4  largestvaccinedrive achieves another milestone...  Twitter for Android
#
#                             source_url  retweet_count  favorite_count lang  \
# 0   http://twitter.com/download/iphone           5273           11800   en
# 1   http://twitter.com/download/iphone           1964            6256   en
# 2            https://www.hootsuite.com            593             624   en
# 3           https://mobile.twitter.com             44               0   en
# 4  http://twitter.com/download/android             41               0   en
#
#                                   full_text_lemmatiz  sentiment  polarity
# 0  [explosive—we, learn, trump, tested, positive,...   0.469697 -0.005682
# 1  [learn, wise, guy, mocked, joe, biden, preside...   0.592929  0.392424
# 2  [covid, update, total, test, conducted, last, ...   0.484242  0.027273
# 3  [early, south, african, data, say, omicron, am...   0.150000  0.050000
# 4  [largestvaccinedrive, achieves, another, miles...   1.000000  0.100000

# %% [markdown]
# #### Sentiment analysis

# %%
def sentiment_analysis(x):
    if x < 0:
        return 'Negative Tweet'
    elif x > 0:
        return 'Positive Tweet'
    else:
        return 'Zero'

# %%
df['sentiment_analysis'] = df['polarity'].apply(sentiment_analysis)
df
# Out:
#                      id               id_str  \
# 0   1465948889761173507  1465948889761173507
# 1   1466046988500230146  1466046988500230146
# 2   1466089777938280452  1466089777938280452
# 3   1466385507298983942  1466385507298983942
# 4   1466385504690008070  1466385504690008070
# ..                  ...                  ...
# 95  1466385233033318400  1466385233033318400
# 96  1466385232387575816  1466385232387575816
# 97  1466385227543203847  1466385227543203847
# 98  1466385226750431234  1466385226750431234
# 99  1466385226314264576  1466385226314264576
#
#                                             full_text               source  \
# 0   explosive—we learn trump tested positive covid...   Twitter for iPhone
# 1   learn wise guy mocked joe biden presidential d...   Twitter for iPhone
# 2   covid update total tests conducted last hrs ne...       Hootsuite Inc.
# 3   early south african data say omicron amp reinf...      Twitter Web App
# 4   largestvaccinedrive achieves another milestone...  Twitter for Android
# ..                                                ...                  ...
# 95           point noted omicron omicronvarient covid  Twitter for Android
# 96  trump test positive covid debate cv fake news ...  Twitter for Android
# 97  covid deaths wales falling recent weeks reduct...  Twitter for Android
# 98  man lied covid meeting gold star families disg...  Twitter for Android
# 99  date country registered confirmed cases covid ...  Twitter for Android
#
#                              source_url  retweet_count  favorite_count lang  \
# 0    http://twitter.com/download/iphone           5273           11800   en
# 1    http://twitter.com/download/iphone           1964            6256   en
# 2             https://www.hootsuite.com            593             624   en
# 3            https://mobile.twitter.com             44               0   en
# 4   http://twitter.com/download/android             41               0   en
# ..                                  ...            ...             ...  ...
# 95  http://twitter.com/download/android              5               0   en
# 96  http://twitter.com/download/android              0               0   en
# 97  http://twitter.com/download/android             12               0   en
# 98  http://twitter.com/download/android              2               0   en
# 99  http://twitter.com/download/android             10               0   en
#
#                                    full_text_lemmatiz  sentiment  polarity  \
# 0   [explosive—we, learn, trump, tested, positive,...   0.469697 -0.005682
# 1   [learn, wise, guy, mocked, joe, biden, preside...   0.592929  0.392424
# 2   [covid, update, total, test, conducted, last, ...   0.484242  0.027273
# 3   [early, south, african, data, say, omicron, am...   0.150000  0.050000
# 4   [largestvaccinedrive, achieves, another, miles...   1.000000  0.100000
# ..                                                ...        ...       ...
# 95     [point, noted, omicron, omicronvarient, covid]   0.000000  0.000000
# 96  [trump, test, positive, covid, debate, cv, fak...   0.681818  0.075758
# 97  [covid, death, wale, falling, recent, week, re...   0.250000  0.000000
# 98  [man, lied, covid, meeting, gold, star, family...   1.000000 -1.000000
# 99  [date, country, registered, confirmed, case, c...   0.700000  0.200000
#
#    sentiment_analysis
# 0      Negative Tweet
# 1      Positive Tweet
# 2      Positive Tweet
# 3      Positive Tweet
# 4      Positive Tweet
# ..                ...
# 95               Zero
# 96     Positive Tweet
# 97               Zero
# 98     Negative Tweet
# 99     Positive Tweet
#
# [100 rows x 12 columns]

# %% [markdown]
# #### Final storing of CSV file

# %%
df.to_csv('final.csv')
